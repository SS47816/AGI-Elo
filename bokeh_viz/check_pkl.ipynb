# %%
import pandas as pd

# ✅ 全局变量：指定你的 pkl 文件路径
# PKL_PATH = "ratings/rating_Glicko_mmlu_1.pkl"
PKL_PATH = "/home/ziggy/AGI-Elo/bokeh_viz/elo_results/action/motion_prediction/Waymo/viz/rating_Glicko_test_case_1.pkl"

def main():
    df = pd.read_pickle(PKL_PATH)

    print(f"文件: {PKL_PATH}")
    print(f"数据类型: {type(df)}")
    print(f"形状: {df.shape}")
    print(f"列名: {list(df.columns)}\n")

    print("每列数据类型:")
    print(df.dtypes)
    print()

    print("前五行直接展示")
    print(df.head())
    print("前五行按列展示:\n")
    for col in df.columns:
        print(f"📌 列: {col}")
        for i, val in enumerate(df[col].head()):
            print(f"  第 {i+1} 行: {val}")
        print()

if __name__ == "__main__":
    main()

# 'id', 'is_success', 'actual_output', 'expected_output', 'gemma-1b'
# 'id', 'title', 'question', 'platform', 'difficulty', 'test_case', 'expected_output'
# 'id', 'title', 'test_case', 'expected_output (from pkl A)', 'actual_output', 'gemma-1b', 'question', 'platform'
# Out:
# 文件: /home/ziggy/AGI-Elo/bokeh_viz/elo_results/action/motion_prediction/Waymo/viz/rating_Glicko_test_case_1.pkl
# 数据类型: <class 'pandas.core.frame.DataFrame'>
# 形状: (44097, 6)
# 列名: ['Label', 'Name', 'Rating', 'Deviation', 'Average Performance', 'Average Score']
#
# 每列数据类型:
# Label                  float64
# Name                    object
# Rating                 float64
# Deviation              float64
# Average Performance    float64
# Average Score          float64
# dtype: object
#
# 前五行直接展示
#        Label              Name       Rating   Deviation  Average Performance  \
# 32667    0.0  36da208f6005d584  2014.348228  155.913132                  0.0
# 12026    0.0  7dac7cc54a244344  2013.580548  155.264183                  0.0
# 8466     0.0  1615586dd1af7ce5  2013.140173  155.252493                  0.0
# 10063    0.0  799cd34cd58e68cd  2012.892077  155.374804                  0.0
# 5457     0.0  478bb71fede88b9f  2012.827621  155.611767                  0.0
#
# ...
